# %% [markdown]
# <a href="https://colab.research.google.com/github/faheema2006/MLOPS/blob/main/SkillSync(One_Hot_Encoding).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-93432c41-f13e-448a-a527-774b1de212e8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-93432c41-f13e-448a-a527-774b1de212e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("clean_resume_dataset.csv")
df
# Out:
#         ResumeID          Category              Name  \
# 0      REAL_0001    Java Developer      Chad Griffin
# 1      REAL_0002    Java Developer    Melinda Thomas
# 2      REAL_0003    Java Developer  Shannon Mccarthy
# 3      REAL_0004    Java Developer  Christine Kelley
# 4      REAL_0005    Java Developer        Karen Holt
# ...          ...               ...               ...
# 3495  SYNTH_3496  Technical Writer      Victor Green
# 3496  SYNTH_3497  Technical Writer        Jim Watson
# 3497  SYNTH_3498  Technical Writer   Katherine Kirby
# 3498  SYNTH_3499  Technical Writer    Denise Schmidt
# 3499  SYNTH_3500  Technical Writer     Stephen White
#
#                            Email  \
# 0              contact@email.com
# 1              contact@email.com
# 2              contact@email.com
# 3              contact@email.com
# 4              contact@email.com
# ...                          ...
# 3495      victor.green@gmail.com
# 3496      jim.watson@hotmail.com
# ...

# %%
dummies = pd.get_dummies(df['Category'])
dummies
# Out:
#       AI Engineer  Backend Developer  Blockchain  Blockchain Developer  \
# 0           False              False       False                 False
# 1           False              False       False                 False
# 2           False              False       False                 False
# 3           False              False       False                 False
# 4           False              False       False                 False
# ...           ...                ...         ...                   ...
# 3495        False              False       False                 False
# 3496        False              False       False                 False
# 3497        False              False       False                 False
# 3498        False              False       False                 False
# 3499        False              False       False                 False
#
#       Business Analyst  Cloud Engineer  Cybersecurity Analyst  Data Science  \
# ...

# %%
merged = pd.concat([df,dummies],axis='columns')
merged
# Out:
#         ResumeID          Category              Name  \
# 0      REAL_0001    Java Developer      Chad Griffin
# 1      REAL_0002    Java Developer    Melinda Thomas
# 2      REAL_0003    Java Developer  Shannon Mccarthy
# 3      REAL_0004    Java Developer  Christine Kelley
# 4      REAL_0005    Java Developer        Karen Holt
# ...          ...               ...               ...
# 3495  SYNTH_3496  Technical Writer      Victor Green
# 3496  SYNTH_3497  Technical Writer        Jim Watson
# 3497  SYNTH_3498  Technical Writer   Katherine Kirby
# 3498  SYNTH_3499  Technical Writer    Denise Schmidt
# 3499  SYNTH_3500  Technical Writer     Stephen White
#
#                            Email  \
# 0              contact@email.com
# 1              contact@email.com
# 2              contact@email.com
# 3              contact@email.com
# 4              contact@email.com
# ...                          ...
# 3495      victor.green@gmail.com
# 3496      jim.watson@hotmail.com
# ...

# %%
final = merged.drop(["Category","Data Science"],axis='columns')
final
# Out:
#         ResumeID              Name                       Email  \
# 0      REAL_0001      Chad Griffin           contact@email.com
# 1      REAL_0002    Melinda Thomas           contact@email.com
# 2      REAL_0003  Shannon Mccarthy           contact@email.com
# 3      REAL_0004  Christine Kelley           contact@email.com
# 4      REAL_0005        Karen Holt           contact@email.com
# ...          ...               ...                         ...
# 3495  SYNTH_3496      Victor Green      victor.green@gmail.com
# 3496  SYNTH_3497        Jim Watson      jim.watson@hotmail.com
# 3497  SYNTH_3498   Katherine Kirby   katherine.kirby@yahoo.com
# 3498  SYNTH_3499    Denise Schmidt  denise.schmidt@hotmail.com
# 3499  SYNTH_3500     Stephen White     stephen.white@gmail.com
#
#                                                   Phone              Location  \
# 0     94105 555 4321000          10                 ...           City, State
# ...

# %%
print("Columns in 'final' DataFrame:")
print(final.columns.tolist())
# Out:
# Columns in 'final' DataFrame:
# ['ResumeID', 'Name', 'Email', 'Phone', 'Location', 'Summary', 'Skills', 'Experience', 'Education', 'Text', 'Source', 'AI Engineer', 'Backend Developer', 'Blockchain', 'Blockchain Developer', 'Business Analyst', 'Cloud Engineer', 'Cybersecurity Analyst', 'Database', 'Database Administrator', 'DevOps', 'Digital Media', 'DotNet Developer', 'ETL Developer', 'Engineering Manager', 'Frontend Developer', 'Full Stack Developer', 'Java Developer', 'Machine Learning Engineer', 'Mobile Developer', 'Network Security Engineer', 'Principal Engineer', 'Product Manager', 'Python Developer', 'QA Engineer', 'React Developer', 'SAP Developer', 'SQL Developer', 'Site Reliability Engineer', 'Software Developer', 'System Administrator', 'Technical Lead', 'Technical Writer', 'Testing', 'UI/UX Designer', 'Web Designing']

# %%
print("Available columns in 'final' DataFrame:")
print(final.columns.tolist())
# Out:
# Available columns in 'final' DataFrame:
# ['ResumeID', 'Name', 'Email', 'Phone', 'Location', 'Summary', 'Skills', 'Experience', 'Education', 'Text', 'Source', 'AI Engineer', 'Backend Developer', 'Blockchain', 'Blockchain Developer', 'Business Analyst', 'Cloud Engineer', 'Cybersecurity Analyst', 'Database', 'Database Administrator', 'DevOps', 'Digital Media', 'DotNet Developer', 'ETL Developer', 'Engineering Manager', 'Frontend Developer', 'Full Stack Developer', 'Java Developer', 'Machine Learning Engineer', 'Mobile Developer', 'Network Security Engineer', 'Principal Engineer', 'Product Manager', 'Python Developer', 'QA Engineer', 'React Developer', 'SAP Developer', 'SQL Developer', 'Site Reliability Engineer', 'Software Developer', 'System Administrator', 'Technical Lead', 'Technical Writer', 'Testing', 'UI/UX Designer', 'Web Designing']

# %%
columns_to_drop_for_X = ['ResumeID', 'Name', 'Email', 'Phone', 'Location', 'Summary', 'Skills', 'Experience', 'Education', 'Text', 'Source', 'AI Engineer']
X = final.drop(columns=columns_to_drop_for_X, axis=1)
y = final['AI Engineer']
print("Shape of X:", X.shape)
print("Shape of y:", y.shape)
# Out:
# Shape of X: (3500, 34)
# Shape of y: (3500,)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.score(X,y)
# Out:
# 0.2467116272212595

# %%
print(X.columns.tolist())
# Out:
# ['Backend Developer', 'Blockchain', 'Blockchain Developer', 'Business Analyst', 'Cloud Engineer', 'Cybersecurity Analyst', 'Database', 'Database Administrator', 'DevOps', 'Digital Media', 'DotNet Developer', 'ETL Developer', 'Engineering Manager', 'Frontend Developer', 'Full Stack Developer', 'Java Developer', 'Machine Learning Engineer', 'Mobile Developer', 'Network Security Engineer', 'Principal Engineer', 'Product Manager', 'Python Developer', 'QA Engineer', 'React Developer', 'SAP Developer', 'SQL Developer', 'Site Reliability Engineer', 'Software Developer', 'System Administrator', 'Technical Lead', 'Technical Writer', 'Testing', 'UI/UX Designer', 'Web Designing']

# %%
feature_columns = X.columns.tolist()
coefficients = model.coef_
intercept = model.intercept_
print(f"Model Intercept (baseline prediction with no other categories): {intercept:.4f}")
X_zero = np.zeros((1, len(feature_columns)))
prediction_zero_features = model.predict(X_zero)
print(f"Prediction for an AI Engineer (given NO other categories are present): {prediction_zero_features[0]:.2f}")
try:
    devops_index = feature_columns.index('DevOps')
    input_data_devops = [0] * len(feature_columns)
    input_data_devops[devops_index] = 1
    X_devops = np.array([input_data_devops])
    prediction_devops = model.predict(X_devops)
    print(f"Prediction for an AI Engineer (given ONLY 'DevOps' is present): {prediction_devops[0]:.2f}")
except ValueError:
    print("'DevOps' not found in feature columns. Please check the column name.")
# Out:
# Model Intercept (baseline prediction with no other categories): 0.2620
# Prediction for an AI Engineer (given NO other categories are present): 0.26
# Prediction for an AI Engineer (given ONLY 'DevOps' is present): -0.00
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
