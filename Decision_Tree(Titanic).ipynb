# %% [markdown]
# <a href="https://colab.research.google.com/github/faheema2006/MLOPS/blob/main/Decision_Tree(Titanic).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-28de69f1-000a-4b2e-afc9-c33acc6ad0f0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-28de69f1-000a-4b2e-afc9-c33acc6ad0f0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
inputs = df[['Pclass','Sex','Age','Fare']]
target = df['Survived']

# %%
dummies = pd.get_dummies(inputs.Sex)
dummies
# Out:
#      female   male
# 0     False   True
# 1      True  False
# 2      True  False
# 3      True  False
# 4     False   True
# ..      ...    ...
# 886   False   True
# 887    True  False
# 888    True  False
# 889   False   True
# 890   False   True
#
# [891 rows x 2 columns]

# %%
inputs = pd.concat([inputs,dummies],axis='columns')
inputs
# Out:
#      Pclass     Sex   Age     Fare  female   male
# 0         3    male  22.0   7.2500   False   True
# 1         1  female  38.0  71.2833    True  False
# 2         3  female  26.0   7.9250    True  False
# 3         1  female  35.0  53.1000    True  False
# 4         3    male  35.0   8.0500   False   True
# ..      ...     ...   ...      ...     ...    ...
# 886       2    male  27.0  13.0000   False   True
# 887       1  female  19.0  30.0000    True  False
# 888       3  female   NaN  23.4500    True  False
# 889       1    male  26.0  30.0000   False   True
# 890       3    male  32.0   7.7500   False   True
#
# [891 rows x 6 columns]

# %%
inputs = inputs.drop('Sex',axis='columns')
inputs
# Out:
#      Pclass   Age     Fare  female   male
# 0         3  22.0   7.2500   False   True
# 1         1  38.0  71.2833    True  False
# 2         3  26.0   7.9250    True  False
# 3         1  35.0  53.1000    True  False
# 4         3  35.0   8.0500   False   True
# ..      ...   ...      ...     ...    ...
# 886       2  27.0  13.0000   False   True
# 887       1  19.0  30.0000    True  False
# 888       3   NaN  23.4500    True  False
# 889       1  26.0  30.0000   False   True
# 890       3  32.0   7.7500   False   True
#
# [891 rows x 5 columns]

# %%
inputs.Age = inputs.Age.fillna(inputs.Age.mean())
inputs
# Out:
#      Pclass        Age     Fare  female   male
# 0         3  22.000000   7.2500   False   True
# 1         1  38.000000  71.2833    True  False
# 2         3  26.000000   7.9250    True  False
# 3         1  35.000000  53.1000    True  False
# 4         3  35.000000   8.0500   False   True
# ..      ...        ...      ...     ...    ...
# 886       2  27.000000  13.0000   False   True
# 887       1  19.000000  30.0000    True  False
# 888       3  29.699118  23.4500    True  False
# 889       1  26.000000  30.0000   False   True
# 890       3  32.000000   7.7500   False   True
#
# [891 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(inputs,target,test_size=0.2)

# %%
from sklearn import tree

# %%
model = tree.DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(X_test,y_test)
# Out:
# 0.7932960893854749

# %%
sample = pd.DataFrame([[3,22,7.25,1,0]],columns=inputs.columns)
prediction = model.predict(sample)
if prediction[0] == 1:
    print("Person Will Survive")
else:
    print("Person Will Not Survive")
# Out:
# Person Will Survive
